# %%
# Q.1
"""ANOVA (Analysis of Variance) is used to compare the means of three or more groups. For it to provide valid results, several assumptions must be met:

Independence: The observations must be independent of each other. This means the outcome of one observation should not influence another.

Example Violation: If you’re studying the effect of different teaching methods on students’ test scores, but some students share study materials or discuss their answers, their scores might not be independent.

Normality: The data within each group should be approximately normally distributed.

Example Violation: If the test scores are heavily skewed or have outliers, the normality assumption may be violated, affecting the accuracy of ANOVA results.

Homogeneity of Variances (Homoscedasticity): The variances of the populations should be equal across the groups.

Example Violation: If one teaching method leads to much higher variability in test scores compared to others, this assumption is violated, potentially leading to incorrect conclusions.

Potential Impacts of Violations:
Independence: Violations can lead to underestimated standard errors and increased Type I error rates, falsely indicating significant differences when there are none.

Normality: If the data is not normally distributed, especially with small sample sizes, the ANOVA results may not be reliable.

Homogeneity of Variances: Violations can cause the F-test to become overly sensitive to group differences, leading to increased Type I errors."""
# Out:
# 'ANOVA (Analysis of Variance) is used to compare the means of three or more groups. For it to provide valid results, several assumptions must be met:\n\nIndependence: The observations must be independent of each other. This means the outcome of one observation should not influence another.\n\nExample Violation: If you’re studying the effect of different teaching methods on students’ test scores, but some students share study materials or discuss their answers, their scores might not be independent.\n\nNormality: The data within each group should be approximately normally distributed.\n\nExample Violation: If the test scores are heavily skewed or have outliers, the normality assumption may be violated, affecting the accuracy of ANOVA results.\n\nHomogeneity of Variances (Homoscedasticity): The variances of the populations should be equal across the groups.\n\nExample Violation: If one teaching method leads to much higher variability in test scores compared to others, this assumption is violated, potentially leading to incorrect conclusions.\n\nPotential Impacts of Violations:\nIndependence: Violations can lead to underestimated standard errors and increased Type I error rates, falsely indicating significant differences when there are none.\n\nNormality: If the data is not normally distributed, especially with small sample sizes, the ANOVA results may not be reliable.\n\nHomogeneity of Variances: Violations can cause the F-test to become overly sensitive to group differences, leading to increased Type I errors.'

# %%
# Q.2
"""There are three main types of ANOVA, each used in different scenarios to compare group means:

One-Way ANOVA:

Situation: Used when you want to compare the means of three or more independent (unrelated) groups.

Example: Comparing the effectiveness of three different diets on weight loss.

Two-Way ANOVA:

Situation: Used when you want to study the effect of two different independent variables on a dependent variable, and to see if there is an interaction between the two variables.

Example: Investigating the effects of both diet and exercise on weight loss, where diet and exercise are the two independent variables.

Repeated Measures ANOVA:

Situation: Used when the same subjects are used for each treatment (like a within-subject design). It’s useful for measuring the changes in subjects over time.

Example: Assessing the impact of a training program on performance, where the same individuals’ performances are measured at different time points (e.g., before, during, and after the training)."""
# Out:
# 'There are three main types of ANOVA, each used in different scenarios to compare group means:\n\nOne-Way ANOVA:\n\nSituation: Used when you want to compare the means of three or more independent (unrelated) groups.\n\nExample: Comparing the effectiveness of three different diets on weight loss.\n\nTwo-Way ANOVA:\n\nSituation: Used when you want to study the effect of two different independent variables on a dependent variable, and to see if there is an interaction between the two variables.\n\nExample: Investigating the effects of both diet and exercise on weight loss, where diet and exercise are the two independent variables.\n\nRepeated Measures ANOVA:\n\nSituation: Used when the same subjects are used for each treatment (like a within-subject design). It’s useful for measuring the changes in subjects over time.\n\nExample: Assessing the impact of a training program on performance, where the same individuals’ performances are measured at different time points (e.g., before, during, and after the training).'

# %%
#Q.3 
'''Partitioning of variance in ANOVA refers to breaking down the total variability observed in data into components attributed to different sources. Here’s the breakdown:

Total Sum of Squares (SST): Represents the total variability in the dataset. It's the sum of the squared differences between each observation and the overall mean.

Between-Group Sum of Squares (SSB): Measures the variability due to the differences between group means. It’s the sum of the squared differences between each group mean and the overall mean, weighted by the number of observations in each group.

Within-Group Sum of Squares (SSW): Measures the variability within each group. It’s the sum of the squared differences between each observation and its respective group mean.

The relationship is: $$ SST = SSB + SSW $$

Importance:
Identifies Sources of Variability: Understanding how much of the total variability is due to differences between groups versus within groups helps researchers identify the impact of the independent variable(s).

Informs Significance Testing: By comparing the between-group and within-group variability, ANOVA assesses whether the observed differences in group means are statistically significant or could have occurred by chance.

Enhances Understanding: Partitioning variance offers a clear picture of the structure of the data, enabling better interpretation and informed decisions.'''
# Out:
# "Partitioning of variance in ANOVA refers to breaking down the total variability observed in data into components attributed to different sources. Here’s the breakdown:\n\nTotal Sum of Squares (SST): Represents the total variability in the dataset. It's the sum of the squared differences between each observation and the overall mean.\n\nBetween-Group Sum of Squares (SSB): Measures the variability due to the differences between group means. It’s the sum of the squared differences between each group mean and the overall mean, weighted by the number of observations in each group.\n\nWithin-Group Sum of Squares (SSW): Measures the variability within each group. It’s the sum of the squared differences between each observation and its respective group mean.\n\nThe relationship is: $$ SST = SSB + SSW $$\n\nImportance:\nIdentifies Sources of Variability: Understanding how much of the total variability is due to differences between groups versus within groups helps researchers identify the impact of the independent variable(s).\n\nInforms Significance Testing: By comparing the between-group and within-group variability, ANOVA assesses whether the observed differences in group means are statistically significant or could have occurred by chance.\n\nEnhances Understanding: Partitioning variance offers a clear picture of the structure of the data, enabling better interpretation and informed decisions."

# %%
# Q.4
import numpy as np

data = {
    'A':[20,30,25],
    'B':[27,29,30],
    'C':[25,28,27]
}

groups = [np.array(values) for values in data.values()]
all_data = np.concatenate(groups)

overall_mean = np.mean(all_data)

sst = np.sum((all_data - overall_mean) ** 2)

ssb = np.sum(len(group) * (np.mean(group) - overall_mean) **2 for group in groups)

sse = sum(np.sum((group - np.mean(group)) **2) for group in groups)

print(f"Total Sum of Squares (SST): {sst}")
print(f"Explained Sum of Squares (SSB or SSE): {ssb}")
print(f"Residual Sum of Squares (SSR or SSE): {sse}")
# Out:
# Total Sum of Squares (SST): 79.55555555555556
# Explained Sum of Squares (SSB or SSE): 20.222222222222236
# Residual Sum of Squares (SSR or SSE): 59.33333333333333
# C:\Users\Rohil\AppData\Local\Temp\ipykernel_2044\2755621193.py:17: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   ssb = np.sum(len(group) * (np.mean(group) - overall_mean) **2 for group in groups)

# %%
# Q.5
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols



# Sample data
data = {
    'Teaching_Method': ['A', 'A', 'A', 'B', 'B', 'B', 'A', 'A', 'A', 'B', 'B', 'B'],
    'Study_Time': ['1 hour', '1 hour', '1 hour', '1 hour', '1 hour', '1 hour', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours'],
    'Test_Score': [88, 92, 85, 91, 89, 90, 90, 94, 93, 95, 92, 96]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Fit the two-way ANOVA model
model = ols('Test_Score ~ C(Teaching_Method) + C(Study_Time) + C(Teaching_Method):C(Study_Time)', data=df).fit()

# Perform the ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)

# Display the results
print(anova_table)
# Out:
#                                      sum_sq   df         F    PR(>F)
# C(Teaching_Method)                10.083333  1.0  1.833333  0.212739
# C(Study_Time)                     52.083333  1.0  9.469697  0.015179
# C(Teaching_Method):C(Study_Time)   0.083333  1.0  0.015152  0.905071
# Residual                          44.000000  8.0       NaN       NaN

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.1.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ---------------------------------------- 233.9/233.9 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\rohil\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Q.6
"""Reject the Null Hypothesis: Since the p-value (0.02) is less than the significance level (commonly 0.05), you reject the null hypothesis. This means there is enough evidence to suggest that at least one of the group means is significantly different from the others.

Interpretation:
F-Statistic (5.23): This value indicates the ratio of variance between the group means to the variance within the groups. A higher F-statistic suggests a greater degree of difference between group means.

P-Value (0.02): The p-value tells you the probability of obtaining an F-statistic at least as extreme as the one observed, assuming the null hypothesis is true. A p-value of 0.02 means there is a 2% chance that the observed differences occurred by random chance.

So, with a p-value of 0.02, you can confidently say that there are statistically significant differences between the group means. """
# Out:
# 'Reject the Null Hypothesis: Since the p-value (0.02) is less than the significance level (commonly 0.05), you reject the null hypothesis. This means there is enough evidence to suggest that at least one of the group means is significantly different from the others.\n\nInterpretation:\nF-Statistic (5.23): This value indicates the ratio of variance between the group means to the variance within the groups. A higher F-statistic suggests a greater degree of difference between group means.\n\nP-Value (0.02): The p-value tells you the probability of obtaining an F-statistic at least as extreme as the one observed, assuming the null hypothesis is true. A p-value of 0.02 means there is a 2% chance that the observed differences occurred by random chance.\n\nSo, with a p-value of 0.02, you can confidently say that there are statistically significant differences between the group means. '

# %%
# Q.7
"""
Handling missing data in repeated measures ANOVA is crucial to maintain the integrity and validity of your analysis. Here’s how you can handle it, along with the potential consequences of different methods:

Methods to Handle Missing Data:
Listwise Deletion (Complete Case Analysis):

What it is: Remove any subject with missing data in any of the repeated measures.

Consequences: Reduces sample size, which can decrease statistical power and potentially bias the results if the missing data are not randomly distributed.

Pairwise Deletion:

What it is: Use all available data by only removing cases with missing data for specific analyses.

Consequences: Maintains a larger sample size but can introduce inconsistencies and may not adequately address the pattern of missing data.

Mean Substitution:

What it is: Replace missing values with the mean of the observed values for that variable.

Consequences: Can underestimate the variability and inflate type I errors (false positives).

Multiple Imputation:

What it is: Replace missing data with a set of plausible values based on other observed data, creating multiple complete datasets and averaging the results.

Consequences: More accurate and robust than mean substitution, but computationally intensive and requires assumptions about the data distribution.

Last Observation Carried Forward (LOCF):

What it is: Replace missing values with the last observed value for that subject.

Consequences: Simple to implement but can lead to biases, especially if the missing data occurs at random times.

Mixed-Effects Models:

What it is: Use statistical models that can handle missing data by including random effects to account for subject-level variation.

Consequences: Flexible and robust, but requires more complex modeling and assumptions about the data structure."""
# Out:
# '\nHandling missing data in repeated measures ANOVA is crucial to maintain the integrity and validity of your analysis. Here’s how you can handle it, along with the potential consequences of different methods:\n\nMethods to Handle Missing Data:\nListwise Deletion (Complete Case Analysis):\n\nWhat it is: Remove any subject with missing data in any of the repeated measures.\n\nConsequences: Reduces sample size, which can decrease statistical power and potentially bias the results if the missing data are not randomly distributed.\n\nPairwise Deletion:\n\nWhat it is: Use all available data by only removing cases with missing data for specific analyses.\n\nConsequences: Maintains a larger sample size but can introduce inconsistencies and may not adequately address the pattern of missing data.\n\nMean Substitution:\n\nWhat it is: Replace missing values with the mean of the observed values for that variable.\n\nConsequences: Can underestimate the variability and inflate type I errors (false positives).\n\nMultiple Imputation:\n\nWhat it is: Replace missing data with a set of plausible values based on other observed data, creating multiple complete datasets and averaging the results.\n\nConsequences: More accurate and robust than mean substitution, but computationally intensive and requires assumptions about the data distribution.\n\nLast Observation Carried Forward (LOCF):\n\nWhat it is: Replace missing values with the last observed value for that subject.\n\nConsequences: Simple to implement but can lead to biases, especially if the missing data occurs at random times.\n\nMixed-Effects Models:\n\nWhat it is: Use statistical models that can handle missing data by including random effects to account for subject-level variation.\n\nConsequences: Flexible and robust, but requires more complex modeling and assumptions about the data structure.'

# %%
#Q.8 
"""Post-Hoc Tests After ANOVA
Post-hoc tests are statistical procedures used to identify which specific groups differ significantly from one another after a significant ANOVA result. These tests are necessary when the ANOVA indicates an overall difference among groups but doesn't specify which groups are different.

Here are some common post-hoc tests:

1. Tukey's HSD (Honestly Significant Difference)
When to use: When you have equal sample sizes across groups and want to control the family-wise error rate (the probability of making at least one Type I error).
Example: Comparing the mean exam scores of students from three different schools.
2. Bonferroni Correction
When to use: When you want to control the family-wise error rate and have a large number of pairwise comparisons.
Example: Comparing the effects of five different fertilizers on plant growth.
3. Sidak Correction
When to use: Similar to Bonferroni but often slightly more powerful (i.e., less likely to miss true differences).
Example: Comparing the effectiveness of four different marketing campaigns on sales.
4. Fisher's LSD (Least Significant Difference)
When to use: When you have equal sample sizes across groups and don't need to control the family-wise error rate strictly.
Example: Comparing the mean blood pressure of patients in three different treatment groups.
5. Scheffé's Test
When to use: When you want to control the family-wise error rate and have a complex set of comparisons (e.g., comparing all possible combinations of groups).
Example: Comparing the effects of three different factors (e.g., temperature, humidity, and light) on plant growth.
Example of when a post-hoc test might be necessary:

Imagine a study comparing the effectiveness of three different teaching methods (Method A, Method B, and Method C) on student test scores. An ANOVA reveals a significant difference among the three methods. However, the ANOVA alone doesn't tell us which method(s) are significantly different from the others. To pinpoint the specific differences, a post-hoc test (e.g., Tukey's HSD) would be used to compare the mean test scores of each method pair."""
# Out:
# "Post-Hoc Tests After ANOVA\nPost-hoc tests are statistical procedures used to identify which specific groups differ significantly from one another after a significant ANOVA result. These tests are necessary when the ANOVA indicates an overall difference among groups but doesn't specify which groups are different.\n\nHere are some common post-hoc tests:\n\n1. Tukey's HSD (Honestly Significant Difference)\nWhen to use: When you have equal sample sizes across groups and want to control the family-wise error rate (the probability of making at least one Type I error).\nExample: Comparing the mean exam scores of students from three different schools.\n2. Bonferroni Correction\nWhen to use: When you want to control the family-wise error rate and have a large number of pairwise comparisons.\nExample: Comparing the effects of five different fertilizers on plant growth.\n3. Sidak Correction\nWhen to use: Similar to Bonferroni but often slightly more powerful (i.e., less likely to miss true differences).\nExample: Comparing the effectiveness of four different marketing campaigns on sales.\n4. Fisher's LSD (Least Significant Difference)\nWhen to use: When you have equal sample sizes across groups and don't need to control the family-wise error rate strictly.\nExample: Comparing the mean blood pressure of patients in three different treatment groups.\n5. Scheffé's Test\nWhen to use: When you want to control the family-wise error rate and have a complex set of comparisons (e.g., comparing all possible combinations of groups).\nExample: Comparing the effects of three different factors (e.g., temperature, humidity, and light) on plant growth.\nExample of when a post-hoc test might be necessary:\n\nImagine a study comparing the effectiveness of three different teaching methods (Method A, Method B, and Method C) on student test scores. An ANOVA reveals a significant difference among the three methods. However, the ANOVA alone doesn't tell us which method(s) are significantly different from the others. To pinpoint the specific differences, a post-hoc test (e.g., Tukey's HSD) would be used to compare the mean test scores of each method pair."

# %%
# Q.9
import pandas as pd
import numpy as np
from scipy.stats import f_oneway

# Example data
data = {
    'Diet A': [2, 3, 2.5, 4, 3.5, 2, 3, 2.5, 4, 3.5, 2, 3, 2.5, 4, 3.5, 2, 3, 2.5, 4, 3.5],
    'Diet B': [3, 4, 3.5, 5, 4.5, 3, 4, 3.5, 5, 4.5, 3, 4, 3.5, 5, 4.5, 3, 4, 3.5, 5, 4.5],
    'Diet C': [1, 1.5, 1, 2, 1.5, 1, 1.5, 1, 2, 1.5, 1, 1.5, 1, 2, 1.5, 1, 1.5, 1, 2, 1.5]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(df['Diet A'], df['Diet B'], df['Diet C'])

print("F-statistic:", f_statistic)
print("P-value:", p_value)
"""Interpretation:
F-statistic: This value indicates the ratio of the variance between group means to the variance within groups. A higher F-statistic suggests a greater degree of difference between group means.

P-value: If the p-value is less than the significance level (e.g., 0.05), it indicates that there are statistically significant differences between the group means.

In this example, you might get results like:


Copy
F-statistic: 40.0
P-value: 1.39e-09
Since the p-value is much less than 0.05, you reject the null hypothesis and conclude that there are significant differences in mean weight loss among the three diets."""
# Out:
# F-statistic: 86.00000000000009
# P-value: 6.125226319567677e-18
# 'Interpretation:\nF-statistic: This value indicates the ratio of the variance between group means to the variance within groups. A higher F-statistic suggests a greater degree of difference between group means.\n\nP-value: If the p-value is less than the significance level (e.g., 0.05), it indicates that there are statistically significant differences between the group means.\n\nIn this example, you might get results like:\n\n\nCopy\nF-statistic: 40.0\nP-value: 1.39e-09\nSince the p-value is much less than 0.05, you reject the null hypothesis and conclude that there are significant differences in mean weight loss among the three diets.'

# %%
# Q.10
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Example data
data = {
    'Software_Program': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C'],
    'Experience_Level': ['Novice', 'Novice', 'Novice', 'Experienced', 'Experienced', 'Experienced', 'Novice', 'Novice', 'Novice', 'Experienced', 'Novice', 'Novice', 'Novice', 'Experienced', 'Experienced', 'Experienced', 'Novice', 'Novice', 'Novice', 'Experienced', 'Novice', 'Novice', 'Novice', 'Experienced', 'Experienced', 'Experienced', 'Novice', 'Novice', 'Novice', 'Experienced'],
    'Completion_Time': [25, 30, 28, 20, 22, 24, 26, 29, 27, 21, 32, 34, 33, 28, 26, 27, 35, 31, 30, 29, 24, 26, 25, 22, 21, 23, 27, 29, 28, 25]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Fit the two-way ANOVA model
model = ols('Completion_Time ~ C(Software_Program) + C(Experience_Level) + C(Software_Program):C(Experience_Level)', data=df).fit()

# Perform the ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)

# Display the results
print(anova_table)
# Out:
#                                          sum_sq    df       F        PR(>F)
# C(Software_Program)                       194.6   2.0  31.136  2.148308e-07
# C(Experience_Level)                       168.2   1.0  53.824  1.410515e-07
# C(Software_Program):C(Experience_Level)     4.9   2.0   0.784  4.679224e-01
# Residual                                   75.0  24.0     NaN           NaN

# %%
# Q.11
import numpy as np
from scipy.stats import ttest_ind

control_group = [70, 68, 75, 73, 71, 69, 72, 74, 76, 70, 71, 73, 69, 72, 74, 75, 70, 73, 71, 68, 71, 69, 75, 73, 70, 74, 72, 71, 70, 69, 75, 72, 74, 71, 73, 70, 69, 74, 72, 71, 70, 69, 73, 72, 70, 71, 74, 73, 71, 70]
experimental_group = [78, 80, 77, 76, 82, 79, 75, 81, 83, 77, 79, 82, 80, 76, 78, 81, 83, 79, 76, 78, 77, 80, 81, 78, 76, 82, 79, 77, 80, 78, 81, 77, 79, 76, 81, 78, 80, 77, 82, 79, 76, 80, 81, 78, 76, 82, 77, 80, 79]

t_statistic , p_value = ttest_ind(control_group , experimental_group)

print("T-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# T-statistic: -17.213085682401932
# p-value: 3.0362969915200846e-31

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Combine data into a DataFrame
df = pd.DataFrame({
    'Group': ['Control'] * len(control_group) + ['Experimental'] * len(experimental_group),
    'Scores': control_group + experimental_group
})

# Perform ANOVA
anova_model = ols('Scores ~ C(Group)', data=df).fit()
anova_table = sm.stats.anova_lm(anova_model, typ=2)
print("ANOVA Table:\n", anova_table)

# Perform Tukey's HSD test
tukey = pairwise_tukeyhsd(endog=df['Scores'], groups=df['Group'], alpha=0.05)
print(tukey)
# Out:
# ANOVA Table:
#                 sum_sq    df           F        PR(>F)
# C(Group)  1310.988349   1.0  296.290319  3.036297e-31
# Residual   429.193469  97.0         NaN           NaN
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1    group2    meandiff p-adj lower  upper  reject
# --------------------------------------------------------
# Control Experimental   7.2784   0.0 6.4391 8.1176   True
# --------------------------------------------------------

# %%
# Q.12
import pandas as pd
import numpy as np
from statsmodels.stats.anova import AnovaRM
from statsmodels.stats.multicomp import MultiComparison

# Example data
data = {
    'Day': np.tile(np.arange(1, 31), 3),
    'Store': np.repeat(['A', 'B', 'C'], 30),
    'Sales': [200, 220, 230, 240, 250, 210, 200, 230, 210, 220, 250, 230, 220, 210, 240, 220, 230, 240, 250, 210, 200, 220, 230, 240, 250, 210, 200, 230, 210, 220,
              210, 230, 240, 250, 260, 220, 210, 240, 220, 230, 260, 240, 230, 220, 250, 230, 240, 250, 260, 220, 210, 230, 240, 250, 260, 220, 210, 240, 220, 230,
              190, 210, 220, 230, 240, 200, 190, 220, 200, 210, 240, 220, 210, 200, 230, 210, 220, 230, 240, 200, 190, 210, 220, 230, 240, 200, 190, 220, 200, 210]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Fit the repeated measures ANOVA model
aovrm = AnovaRM(df, 'Sales', 'Day', within=['Store']).fit()

# Perform the repeated measures ANOVA
anova_table = aovrm.summary()
print(anova_table)

# Post-hoc test using Tukey's HSD
df['Group'] = df['Day'].astype(str) + df['Store']
mc = MultiComparison(df['Sales'], df['Group'])
post_hoc_res = mc.tukeyhsd()
print(post_hoc_res)
# Out:
#                              Anova
# ===============================================================
#                     F Value               Num DF  Den DF Pr > F
# ---------------------------------------------------------------
# Store 139328309725521489401368018944.0000 2.0000 58.0000 0.0000
# ===============================================================
# C:\Users\Rohil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\fromnumeric.py:4318: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\Rohil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#    10A    10B     10.0   nan   nan   nan  False
#    10A    10C    -10.0   nan   nan   nan  False
#    10A    11A     30.0   nan   nan   nan  False
#    10A    11B     40.0   nan   nan   nan  False
#    10A    11C     20.0   nan   nan   nan  False
#    10A    12A     10.0   nan   nan   nan  False
#    10A    12B     20.0   nan   nan   nan  False
#    10A    12C      0.0   nan   nan   nan  False
#    10A    13A      0.0   nan   nan   nan  False
#    10A    13B     10.0   nan   nan   nan  False
#    10A    13C    -10.0   nan   nan   nan  False
#    10A    14A    -10.0   nan   nan   nan  False
#    10A    14B      0.0   nan   nan   nan  False
#    10A    14C    -20.0   nan   nan   nan  False
#    10A    15A     20.0   nan   nan   nan  False
#    10A    15B     30.0   nan   nan   nan  False
#    10A    15C     10.0   nan   nan   nan  False
#    10A    16A      0.0   nan   nan   nan  False
#    10A    16B     10.0   nan   nan   nan  False
#    10A    16C    -10.0   nan   nan   nan  False
#    10A    17A     10.0   nan   nan   nan  False
#    10A    17B     20.0   nan   nan   nan  False
#    10A    17C      0.0   nan   nan   nan  False
#    10A    18A     20.0   nan   nan   nan  False
#    10A    18B     30.0   nan   nan   nan  False
#    10A    18C     10.0   nan   nan   nan  False
#    10A    19A     30.0   nan   nan   nan  False
#    10A    19B     40.0   nan   nan   nan  False
#    10A    19C     20.0   nan   nan   nan  False
#    10A     1A    -20.0   nan   nan   nan  False
#    10A     1B    -10.0   nan   nan   nan  False
#    10A     1C    -30.0   nan   nan   nan  False
#    10A    20A    -10.0   nan   nan   nan  False
#    10A    20B      0.0   nan   nan   nan  False
#    10A    20C    -20.0   nan   nan   nan  False
#    10A    21A    -20.0   nan   nan   nan  False
#    10A    21B    -10.0   nan   nan   nan  False
#    10A    21C    -30.0   nan   nan   nan  False
#    10A    22A      0.0   nan   nan   nan  False
#    10A    22B     10.0   nan   nan   nan  False
#    10A    22C    -10.0   nan   nan   nan  False
#    10A    23A     10.0   nan   nan   nan  False
#    10A    23B     20.0   nan   nan   nan  False
#    10A    23C      0.0   nan   nan   nan  False
#    10A    24A     20.0   nan   nan   nan  False
#    10A    24B     30.0   nan   nan   nan  False
#    10A    24C     10.0   nan   nan   nan  False
#    10A    25A     30.0   nan   nan   nan  False
#    10A    25B     40.0   nan   nan   nan  False
#    10A    25C     20.0   nan   nan   nan  False
#    10A    26A    -10.0   nan   nan   nan  False
#    10A    26B      0.0   nan   nan   nan  False
#    10A    26C    -20.0   nan   nan   nan  False
#    10A    27A    -20.0   nan   nan   nan  False
#    10A    27B    -10.0   nan   nan   nan  False
#    10A    27C    -30.0   nan   nan   nan  False
#    10A    28A     10.0   nan   nan   nan  False
#    10A    28B     20.0   nan   nan   nan  False
#    10A    28C      0.0   nan   nan   nan  False
#    10A    29A    -10.0   nan   nan   nan  False
#    10A    29B      0.0   nan   nan   nan  False
#    10A    29C    -20.0   nan   nan   nan  False
#    10A     2A      0.0   nan   nan   nan  False
#    10A     2B     10.0   nan   nan   nan  False
#    10A     2C    -10.0   nan   nan   nan  False
#    10A    30A      0.0   nan   nan   nan  False
#    10A    30B     10.0   nan   nan   nan  False
#    10A    30C    -10.0   nan   nan   nan  False
#    10A     3A     10.0   nan   nan   nan  False
#    10A     3B     20.0   nan   nan   nan  False
#    10A     3C      0.0   nan   nan   nan  False
#    10A     4A     20.0   nan   nan   nan  False
#    10A     4B     30.0   nan   nan   nan  False
#    10A     4C     10.0   nan   nan   nan  False
#    10A     5A     30.0   nan   nan   nan  False
#    10A     5B     40.0   nan   nan   nan  False
#    10A     5C     20.0   nan   nan   nan  False
#    10A     6A    -10.0   nan   nan   nan  False
#    10A     6B      0.0   nan   nan   nan  False
#    10A     6C    -20.0   nan   nan   nan  False
#    10A     7A    -20.0   nan   nan   nan  False
#    10A     7B    -10.0   nan   nan   nan  False
#    10A     7C    -30.0   nan   nan   nan  False
#    10A     8A     10.0   nan   nan   nan  False
#    10A     8B     20.0   nan   nan   nan  False
#    10A     8C      0.0   nan   nan   nan  False
#    10A     9A    -10.0   nan   nan   nan  False
#    10A     9B      0.0   nan   nan   nan  False
#    10A     9C    -20.0   nan   nan   nan  False
#    10B    10C    -20.0   nan   nan   nan  False
#    10B    11A     20.0   nan   nan   nan  False
#    10B    11B     30.0   nan   nan   nan  False
#    10B    11C     10.0   nan   nan   nan  False
#    10B    12A      0.0   nan   nan   nan  False
#    10B    12B     10.0   nan   nan   nan  False
#    10B    12C    -10.0   nan   nan   nan  False
#    10B    13A    -10.0   nan   nan   nan  False
#    10B    13B      0.0   nan   nan   nan  False
#    10B    13C    -20.0   nan   nan   nan  False
#    10B    14A    -20.0   nan   nan   nan  False
#    10B    14B    -10.0   nan   nan   nan  False
#    10B    14C    -30.0   nan   nan   nan  False
#    10B    15A     10.0   nan   nan   nan  False
#    10B    15B     20.0   nan   nan   nan  False
#    10B    15C      0.0   nan   nan   nan  False
#    10B    16A    -10.0   nan   nan   nan  False
#    10B    16B      0.0   nan   nan   nan  False
#    10B    16C    -20.0   nan   nan   nan  False
#    10B    17A      0.0   nan   nan   nan  False
#    10B    17B     10.0   nan   nan   nan  False
#    10B    17C    -10.0   nan   nan   nan  False
#    10B    18A     10.0   nan   nan   nan  False
#    10B    18B     20.0   nan   nan   nan  False
#    10B    18C      0.0   nan   nan   nan  False
#    10B    19A     20.0   nan   nan   nan  False
#    10B    19B     30.0   nan   nan   nan  False
#    10B    19C     10.0   nan   nan   nan  False
#    10B     1A    -30.0   nan   nan   nan  False
#    10B     1B    -20.0   nan   nan   nan  False
#    10B     1C    -40.0   nan   nan   nan  False
#    10B    20A    -20.0   nan   nan   nan  False
#    10B    20B    -10.0   nan   nan   nan  False
#    10B    20C    -30.0   nan   nan   nan  False
#    10B    21A    -30.0   nan   nan   nan  False
#    10B    21B    -20.0   nan   nan   nan  False
#    10B    21C    -40.0   nan   nan   nan  False
#    10B    22A    -10.0   nan   nan   nan  False
#    10B    22B      0.0   nan   nan   nan  False
#    10B    22C    -20.0   nan   nan   nan  False
#    10B    23A      0.0   nan   nan   nan  False
#    10B    23B     10.0   nan   nan   nan  False
#    10B    23C    -10.0   nan   nan   nan  False
#    10B    24A     10.0   nan   nan   nan  False
#    10B    24B     20.0   nan   nan   nan  False
#    10B    24C      0.0   nan   nan   nan  False
#    10B    25A     20.0   nan   nan   nan  False
#    10B    25B     30.0   nan   nan   nan  False
#    10B    25C     10.0   nan   nan   nan  False
#    10B    26A    -20.0   nan   nan   nan  False
#    10B    26B    -10.0   nan   nan   nan  False
#    10B    26C    -30.0   nan   nan   nan  False
#    10B    27A    -30.0   nan   nan   nan  False
#    10B    27B    -20.0   nan   nan   nan  False
#    10B    27C    -40.0   nan   nan   nan  False
#    10B    28A      0.0   nan   nan   nan  False
#    10B    28B     10.0   nan   nan   nan  False
#    10B    28C    -10.0   nan   nan   nan  False
#    10B    29A    -20.0   nan   nan   nan  False
#    10B    29B    -10.0   nan   nan   nan  False
#    10B    29C    -30.0   nan   nan   nan  False
#    10B     2A    -10.0   nan   nan   nan  False
#    10B     2B      0.0   nan   nan   nan  False
#    10B     2C    -20.0   nan   nan   nan  False
#    10B    30A    -10.0   nan   nan   nan  False
#    10B    30B      0.0   nan   nan   nan  False
#    10B    30C    -20.0   nan   nan   nan  False
#    10B     3A      0.0   nan   nan   nan  False
#    10B     3B     10.0   nan   nan   nan  False
#    10B     3C    -10.0   nan   nan   nan  False
#    10B     4A     10.0   nan   nan   nan  False
#    10B     4B     20.0   nan   nan   nan  False
#    10B     4C      0.0   nan   nan   nan  False
#    10B     5A     20.0   nan   nan   nan  False
#    10B     5B     30.0   nan   nan   nan  False
#    10B     5C     10.0   nan   nan   nan  False
#    10B     6A    -20.0   nan   nan   nan  False
#    10B     6B    -10.0   nan   nan   nan  False
#    10B     6C    -30.0   nan   nan   nan  False
#    10B     7A    -30.0   nan   nan   nan  False
#    10B     7B    -20.0   nan   nan   nan  False
#    10B     7C    -40.0   nan   nan   nan  False
#    10B     8A      0.0   nan   nan   nan  False
#    10B     8B     10.0   nan   nan   nan  False
#    10B     8C    -10.0   nan   nan   nan  False
#    10B     9A    -20.0   nan   nan   nan  False
#    10B     9B    -10.0   nan   nan   nan  False
#    10B     9C    -30.0   nan   nan   nan  False
#    10C    11A     40.0   nan   nan   nan  False
#    10C    11B     50.0   nan   nan   nan  False
#    10C    11C     30.0   nan   nan   nan  False
#    10C    12A     20.0   nan   nan   nan  False
#    10C    12B     30.0   nan   nan   nan  False
#    10C    12C     10.0   nan   nan   nan  False
#    10C    13A     10.0   nan   nan   nan  False
#    10C    13B     20.0   nan   nan   nan  False
#    10C    13C      0.0   nan   nan   nan  False
#    10C    14A      0.0   nan   nan   nan  False
#    10C    14B     10.0   nan   nan   nan  False
#    10C    14C    -10.0   nan   nan   nan  False
#    10C    15A     30.0   nan   nan   nan  False
#    10C    15B     40.0   nan   nan   nan  False
#    10C    15C     20.0   nan   nan   nan  False
#    10C    16A     10.0   nan   nan   nan  False
#    10C    16B     20.0   nan   nan   nan  False
#    10C    16C      0.0   nan   nan   nan  False
#    10C    17A     20.0   nan   nan   nan  False
#    10C    17B     30.0   nan   nan   nan  False
#    10C    17C     10.0   nan   nan   nan  False
#    10C    18A     30.0   nan   nan   nan  False
#    10C    18B     40.0   nan   nan   nan  False
#    10C    18C     20.0   nan   nan   nan  False
#    10C    19A     40.0   nan   nan   nan  False
#    10C    19B     50.0   nan   nan   nan  False
#    10C    19C     30.0   nan   nan   nan  False
#    10C     1A    -10.0   nan   nan   nan  False
#    10C     1B      0.0   nan   nan   nan  False
#    10C     1C    -20.0   nan   nan   nan  False
#    10C    20A      0.0   nan   nan   nan  False
#    10C    20B     10.0   nan   nan   nan  False
#    10C    20C    -10.0   nan   nan   nan  False
#    10C    21A    -10.0   nan   nan   nan  False
#    10C    21B      0.0   nan   nan   nan  False
#    10C    21C    -20.0   nan   nan   nan  False
#    10C    22A     10.0   nan   nan   nan  False
#    10C    22B     20.0   nan   nan   nan  False
#    10C    22C      0.0   nan   nan   nan  False
#    10C    23A     20.0   nan   nan   nan  False
#    10C    23B     30.0   nan   nan   nan  False
#    10C    23C     10.0   nan   nan   nan  False
#    10C    24A     30.0   nan   nan   nan  False
#    10C    24B     40.0   nan   nan   nan  False
#    10C    24C     20.0   nan   nan   nan  False
#    10C    25A     40.0   nan   nan   nan  False
#    10C    25B     50.0   nan   nan   nan  False
#    10C    25C     30.0   nan   nan   nan  False
#    10C    26A      0.0   nan   nan   nan  False
#    10C    26B     10.0   nan   nan   nan  False
#    10C    26C    -10.0   nan   nan   nan  False
#    10C    27A    -10.0   nan   nan   nan  False
#    10C    27B      0.0   nan   nan   nan  False
#    10C    27C    -20.0   nan   nan   nan  False
#    10C    28A     20.0   nan   nan   nan  False
#    10C    28B     30.0   nan   nan   nan  False
#    10C    28C     10.0   nan   nan   nan  False
#    10C    29A      0.0   nan   nan   nan  False
#    10C    29B     10.0   nan   nan   nan  False
#    10C    29C    -10.0   nan   nan   nan  False
#    10C     2A     10.0   nan   nan   nan  False
#    10C     2B     20.0   nan   nan   nan  False
#    10C     2C      0.0   nan   nan   nan  False
#    10C    30A     10.0   nan   nan   nan  False
#    10C    30B     20.0   nan   nan   nan  False
#    10C    30C      0.0   nan   nan   nan  False
#    10C     3A     20.0   nan   nan   nan  False
#    10C     3B     30.0   nan   nan   nan  False
#    10C     3C     10.0   nan   nan   nan  False
#    10C     4A     30.0   nan   nan   nan  False
#    10C     4B     40.0   nan   nan   nan  False
#    10C     4C     20.0   nan   nan   nan  False
#    10C     5A     40.0   nan   nan   nan  False
#    10C     5B     50.0   nan   nan   nan  False
#    10C     5C     30.0   nan   nan   nan  False
#    10C     6A      0.0   nan   nan   nan  False
#    10C     6B     10.0   nan   nan   nan  False
#    10C     6C    -10.0   nan   nan   nan  False
#    10C     7A    -10.0   nan   nan   nan  False
#    10C     7B      0.0   nan   nan   nan  False
#    10C     7C    -20.0   nan   nan   nan  False
#    10C     8A     20.0   nan   nan   nan  False
#    10C     8B     30.0   nan   nan   nan  False
#    10C     8C     10.0   nan   nan   nan  False
#    10C     9A      0.0   nan   nan   nan  False
#    10C     9B     10.0   nan   nan   nan  False
#    10C     9C    -10.0   nan   nan   nan  False
#    11A    11B     10.0   nan   nan   nan  False
#    11A    11C    -10.0   nan   nan   nan  False
#    11A    12A    -20.0   nan   nan   nan  False
#    11A    12B    -10.0   nan   nan   nan  False
#    11A    12C    -30.0   nan   nan   nan  False
#    11A    13A    -30.0   nan   nan   nan  False
#    11A    13B    -20.0   nan   nan   nan  False
#    11A    13C    -40.0   nan   nan   nan  False
#    11A    14A    -40.0   nan   nan   nan  False
#    11A    14B    -30.0   nan   nan   nan  False
#    11A    14C    -50.0   nan   nan   nan  False
#    11A    15A    -10.0   nan   nan   nan  False
#    11A    15B      0.0   nan   nan   nan  False
#    11A    15C    -20.0   nan   nan   nan  False
#    11A    16A    -30.0   nan   nan   nan  False
#    11A    16B    -20.0   nan   nan   nan  False
#    11A    16C    -40.0   nan   nan   nan  False
#    11A    17A    -20.0   nan   nan   nan  False
#    11A    17B    -10.0   nan   nan   nan  False
#    11A    17C    -30.0   nan   nan   nan  False
#    11A    18A    -10.0   nan   nan   nan  False
#    11A    18B      0.0   nan   nan   nan  False
#    11A    18C    -20.0   nan   nan   nan  False
#    11A    19A      0.0   nan   nan   nan  False
#    11A    19B     10.0   nan   nan   nan  False
#    11A    19C    -10.0   nan   nan   nan  False
#    11A     1A    -50.0   nan   nan   nan  False
#    11A     1B    -40.0   nan   nan   nan  False
#    11A     1C    -60.0   nan   nan   nan  False
#    11A    20A    -40.0   nan   nan   nan  False
#    11A    20B    -30.0   nan   nan   nan  False
#    11A    20C    -50.0   nan   nan   nan  False
#    11A    21A    -50.0   nan   nan   nan  False
#    11A    21B    -40.0   nan   nan   nan  False
#    11A    21C    -60.0   nan   nan   nan  False
#    11A    22A    -30.0   nan   nan   nan  False
#    11A    22B    -20.0   nan   nan   nan  False
#    11A    22C    -40.0   nan   nan   nan  False
#    11A    23A    -20.0   nan   nan   nan  False
#    11A    23B    -10.0   nan   nan   nan  False
#    11A    23C    -30.0   nan   nan   nan  False
#    11A    24A    -10.0   nan   nan   nan  False
#    11A    24B      0.0   nan   nan   nan  False
#    11A    24C    -20.0   nan   nan   nan  False
#    11A    25A      0.0   nan   nan   nan  False
#    11A    25B     10.0   nan   nan   nan  False
#    11A    25C    -10.0   nan   nan   nan  False
#    11A    26A    -40.0   nan   nan   nan  False
#    11A    26B    -30.0   nan   nan   nan  False
#    11A    26C    -50.0   nan   nan   nan  False
#    11A    27A    -50.0   nan   nan   nan  False
#    11A    27B    -40.0   nan   nan   nan  False
#    11A    27C    -60.0   nan   nan   nan  False
#    11A    28A    -20.0   nan   nan   nan  False
#    11A    28B    -10.0   nan   nan   nan  False
#    11A    28C    -30.0   nan   nan   nan  False
#    11A    29A    -40.0   nan   nan   nan  False
#    11A    29B    -30.0   nan   nan   nan  False
#    11A    29C    -50.0   nan   nan   nan  False
#    11A     2A    -30.0   nan   nan   nan  False
#    11A     2B    -20.0   nan   nan   nan  False
#    11A     2C    -40.0   nan   nan   nan  False
#    11A    30A    -30.0   nan   nan   nan  False
#    11A    30B    -20.0   nan   nan   nan  False
#    11A    30C    -40.0   nan   nan   nan  False
#    11A     3A    -20.0   nan   nan   nan  False
#    11A     3B    -10.0   nan   nan   nan  False
#    11A     3C    -30.0   nan   nan   nan  False
#    11A     4A    -10.0   nan   nan   nan  False
#    11A     4B      0.0   nan   nan   nan  False
#    11A     4C    -20.0   nan   nan   nan  False
#    11A     5A      0.0   nan   nan   nan  False
#    11A     5B     10.0   nan   nan   nan  False
#    11A     5C    -10.0   nan   nan   nan  False
#    11A     6A    -40.0   nan   nan   nan  False
#    11A     6B    -30.0   nan   nan   nan  False
#    11A     6C    -50.0   nan   nan   nan  False
#    11A     7A    -50.0   nan   nan   nan  False
#    11A     7B    -40.0   nan   nan   nan  False
#    11A     7C    -60.0   nan   nan   nan  False
#    11A     8A    -20.0   nan   nan   nan  False
#    11A     8B    -10.0   nan   nan   nan  False
#    11A     8C    -30.0   nan   nan   nan  False
#    11A     9A    -40.0   nan   nan   nan  False
#    11A     9B    -30.0   nan   nan   nan  False
#    11A     9C    -50.0   nan   nan   nan  False
#    11B    11C    -20.0   nan   nan   nan  False
#    11B    12A    -30.0   nan   nan   nan  False
#    11B    12B    -20.0   nan   nan   nan  False
#    11B    12C    -40.0   nan   nan   nan  False
#    11B    13A    -40.0   nan   nan   nan  False
#    11B    13B    -30.0   nan   nan   nan  False
#    11B    13C    -50.0   nan   nan   nan  False
#    11B    14A    -50.0   nan   nan   nan  False
#    11B    14B    -40.0   nan   nan   nan  False
#    11B    14C    -60.0   nan   nan   nan  False
#    11B    15A    -20.0   nan   nan   nan  False
#    11B    15B    -10.0   nan   nan   nan  False
#    11B    15C    -30.0   nan   nan   nan  False
#    11B    16A    -40.0   nan   nan   nan  False
#    11B    16B    -30.0   nan   nan   nan  False
#    11B    16C    -50.0   nan   nan   nan  False
#    11B    17A    -30.0   nan   nan   nan  False
#    11B    17B    -20.0   nan   nan   nan  False
#    11B    17C    -40.0   nan   nan   nan  False
#    11B    18A    -20.0   nan   nan   nan  False
#    11B    18B    -10.0   nan   nan   nan  False
#    11B    18C    -30.0   nan   nan   nan  False
#    11B    19A    -10.0   nan   nan   nan  False
#    11B    19B      0.0   nan   nan   nan  False
#    11B    19C    -20.0   nan   nan   nan  False
#    11B     1A    -60.0   nan   nan   nan  False
#    11B     1B    -50.0   nan   nan   nan  False
#    11B     1C    -70.0   nan   nan   nan  False
#    11B    20A    -50.0   nan   nan   nan  False
#    11B    20B    -40.0   nan   nan   nan  False
#    11B    20C    -60.0   nan   nan   nan  False
#    11B    21A    -60.0   nan   nan   nan  False
#    11B    21B    -50.0   nan   nan   nan  False
#    11B    21C    -70.0   nan   nan   nan  False
#    11B    22A    -40.0   nan   nan   nan  False
#    11B    22B    -30.0   nan   nan   nan  False
#    11B    22C    -50.0   nan   nan   nan  False
#    11B    23A    -30.0   nan   nan   nan  False
#    11B    23B    -20.0   nan   nan   nan  False
#    11B    23C    -40.0   nan   nan   nan  False
#    11B    24A    -20.0   nan   nan   nan  False
#    11B    24B    -10.0   nan   nan   nan  False
#    11B    24C    -30.0   nan   nan   nan  False
#    11B    25A    -10.0   nan   nan   nan  False
#    11B    25B      0.0   nan   nan   nan  False
#    11B    25C    -20.0   nan   nan   nan  False
#    11B    26A    -50.0   nan   nan   nan  False
#    11B    26B    -40.0   nan   nan   nan  False
#    11B    26C    -60.0   nan   nan   nan  False
#    11B    27A    -60.0   nan   nan   nan  False
#    11B    27B    -50.0   nan   nan   nan  False
#    11B    27C    -70.0   nan   nan   nan  False
#    11B    28A    -30.0   nan   nan   nan  False
#    11B    28B    -20.0   nan   nan   nan  False
#    11B    28C    -40.0   nan   nan   nan  False
#    11B    29A    -50.0   nan   nan   nan  False
#    11B    29B    -40.0   nan   nan   nan  False
#    11B    29C    -60.0   nan   nan   nan  False
#    11B     2A    -40.0   nan   nan   nan  False
#    11B     2B    -30.0   nan   nan   nan  False
#    11B     2C    -50.0   nan   nan   nan  False
#    11B    30A    -40.0   nan   nan   nan  False
#    11B    30B    -30.0   nan   nan   nan  False
#    11B    30C    -50.0   nan   nan   nan  False
#    11B     3A    -30.0   nan   nan   nan  False
#    11B     3B    -20.0   nan   nan   nan  False
#    11B     3C    -40.0   nan   nan   nan  False
#    11B     4A    -20.0   nan   nan   nan  False
#    11B     4B    -10.0   nan   nan   nan  False
#    11B     4C    -30.0   nan   nan   nan  False
#    11B     5A    -10.0   nan   nan   nan  False
#    11B     5B      0.0   nan   nan   nan  False
#    11B     5C    -20.0   nan   nan   nan  False
#    11B     6A    -50.0   nan   nan   nan  False
#    11B     6B    -40.0   nan   nan   nan  False
#    11B     6C    -60.0   nan   nan   nan  False
#    11B     7A    -60.0   nan   nan   nan  False
#    11B     7B    -50.0   nan   nan   nan  False
#    11B     7C    -70.0   nan   nan   nan  False
#    11B     8A    -30.0   nan   nan   nan  False
#    11B     8B    -20.0   nan   nan   nan  False
#    11B     8C    -40.0   nan   nan   nan  False
#    11B     9A    -50.0   nan   nan   nan  False
#    11B     9B    -40.0   nan   nan   nan  False
#    11B     9C    -60.0   nan   nan   nan  False
#    11C    12A    -10.0   nan   nan   nan  False
#    11C    12B      0.0   nan   nan   nan  False
#    11C    12C    -20.0   nan   nan   nan  False
#    11C    13A    -20.0   nan   nan   nan  False
#    11C    13B    -10.0   nan   nan   nan  False
#    11C    13C    -30.0   nan   nan   nan  False
#    11C    14A    -30.0   nan   nan   nan  False
#    11C    14B    -20.0   nan   nan   nan  False
#    11C    14C    -40.0   nan   nan   nan  False
#    11C    15A      0.0   nan   nan   nan  False
#    11C    15B     10.0   nan   nan   nan  False
#    11C    15C    -10.0   nan   nan   nan  False
#    11C    16A    -20.0   nan   nan   nan  False
#    11C    16B    -10.0   nan   nan   nan  False
#    11C    16C    -30.0   nan   nan   nan  False
#    11C    17A    -10.0   nan   nan   nan  False
#    11C    17B      0.0   nan   nan   nan  False
#    11C    17C    -20.0   nan   nan   nan  False
#    11C    18A      0.0   nan   nan   nan  False
#    11C    18B     10.0   nan   nan   nan  False
#    11C    18C    -10.0   nan   nan   nan  False
#    11C    19A     10.0   nan   nan   nan  False
#    11C    19B     20.0   nan   nan   nan  False
#    11C    19C      0.0   nan   nan   nan  False
#    11C     1A    -40.0   nan   nan   nan  False
#    11C     1B    -30.0   nan   nan   nan  False
#    11C     1C    -50.0   nan   nan   nan  False
#    11C    20A    -30.0   nan   nan   nan  False
#    11C    20B    -20.0   nan   nan   nan  False
#    11C    20C    -40.0   nan   nan   nan  False
#    11C    21A    -40.0   nan   nan   nan  False
#    11C    21B    -30.0   nan   nan   nan  False
#    11C    21C    -50.0   nan   nan   nan  False
#    11C    22A    -20.0   nan   nan   nan  False
#    11C    22B    -10.0   nan   nan   nan  False
#    11C    22C    -30.0   nan   nan   nan  False
#    11C    23A    -10.0   nan   nan   nan  False
#    11C    23B      0.0   nan   nan   nan  False
#    11C    23C    -20.0   nan   nan   nan  False
#    11C    24A      0.0   nan   nan   nan  False
#    11C    24B     10.0   nan   nan   nan  False
#    11C    24C    -10.0   nan   nan   nan  False
#    11C    25A     10.0   nan   nan   nan  False
#    11C    25B     20.0   nan   nan   nan  False
#    11C    25C      0.0   nan   nan   nan  False
#    11C    26A    -30.0   nan   nan   nan  False
#    11C    26B    -20.0   nan   nan   nan  False
#    11C    26C    -40.0   nan   nan   nan  False
#    11C    27A    -40.0   nan   nan   nan  False
#    11C    27B    -30.0   nan   nan   nan  False
#    11C    27C    -50.0   nan   nan   nan  False
#    11C    28A    -10.0   nan   nan   nan  False
#    11C    28B      0.0   nan   nan   nan  False
#    11C    28C    -20.0   nan   nan   nan  False
#    11C    29A    -30.0   nan   nan   nan  False
#    11C    29B    -20.0   nan   nan   nan  False
#    11C    29C    -40.0   nan   nan   nan  False
#    11C     2A    -20.0   nan   nan   nan  False
#    11C     2B    -10.0   nan   nan   nan  False
#    11C     2C    -30.0   nan   nan   nan  False
#    11C    30A    -20.0   nan   nan   nan  False
#    11C    30B    -10.0   nan   nan   nan  False
#    11C    30C    -30.0   nan   nan   nan  False
#    11C     3A    -10.0   nan   nan   nan  False
#    11C     3B      0.0   nan   nan   nan  False
#    11C     3C    -20.0   nan   nan   nan  False
#    11C     4A      0.0   nan   nan   nan  False
#    11C     4B     10.0   nan   nan   nan  False
#    11C     4C    -10.0   nan   nan   nan  False
#    11C     5A     10.0   nan   nan   nan  False
#    11C     5B     20.0   nan   nan   nan  False
#    11C     5C      0.0   nan   nan   nan  False
#    11C     6A    -30.0   nan   nan   nan  False
#    11C     6B    -20.0   nan   nan   nan  False
#    11C     6C    -40.0   nan   nan   nan  False
#    11C     7A    -40.0   nan   nan   nan  False
#    11C     7B    -30.0   nan   nan   nan  False
#    11C     7C    -50.0   nan   nan   nan  False
#    11C     8A    -10.0   nan   nan   nan  False
#    11C     8B      0.0   nan   nan   nan  False
#    11C     8C    -20.0   nan   nan   nan  False
#    11C     9A    -30.0   nan   nan   nan  False
#    11C     9B    -20.0   nan   nan   nan  False
#    11C     9C    -40.0   nan   nan   nan  False
#    12A    12B     10.0   nan   nan   nan  False
#    12A    12C    -10.0   nan   nan   nan  False
#    12A    13A    -10.0   nan   nan   nan  False
#    12A    13B      0.0   nan   nan   nan  False
#    12A    13C    -20.0   nan   nan   nan  False
#    12A    14A    -20.0   nan   nan   nan  False
#    12A    14B    -10.0   nan   nan   nan  False
#    12A    14C    -30.0   nan   nan   nan  False
#    12A    15A     10.0   nan   nan   nan  False
#    12A    15B     20.0   nan   nan   nan  False
#    12A    15C      0.0   nan   nan   nan  False
#    12A    16A    -10.0   nan   nan   nan  False
#    12A    16B      0.0   nan   nan   nan  False
#    12A    16C    -20.0   nan   nan   nan  False
#    12A    17A      0.0   nan   nan   nan  False
#    12A    17B     10.0   nan   nan   nan  False
#    12A    17C    -10.0   nan   nan   nan  False
#    12A    18A     10.0   nan   nan   nan  False
#    12A    18B     20.0   nan   nan   nan  False
#    12A    18C      0.0   nan   nan   nan  False
#    12A    19A     20.0   nan   nan   nan  False
#    12A    19B     30.0   nan   nan   nan  False
#    12A    19C     10.0   nan   nan   nan  False
#    12A     1A    -30.0   nan   nan   nan  False
#    12A     1B    -20.0   nan   nan   nan  False
#    12A     1C    -40.0   nan   nan   nan  False
#    12A    20A    -20.0   nan   nan   nan  False
#    12A    20B    -10.0   nan   nan   nan  False
#    12A    20C    -30.0   nan   nan   nan  False
#    12A    21A    -30.0   nan   nan   nan  False
#    12A    21B    -20.0   nan   nan   nan  False
#    12A    21C    -40.0   nan   nan   nan  False
#    12A    22A    -10.0   nan   nan   nan  False
#    12A    22B      0.0   nan   nan   nan  False
#    12A    22C    -20.0   nan   nan   nan  False
#    12A    23A      0.0   nan   nan   nan  False
#    12A    23B     10.0   nan   nan   nan  False
#    12A    23C    -10.0   nan   nan   nan  False
#    12A    24A     10.0   nan   nan   nan  False
#    12A    24B     20.0   nan   nan   nan  False
#    12A    24C      0.0   nan   nan   nan  False
#    12A    25A     20.0   nan   nan   nan  False
#    12A    25B     30.0   nan   nan   nan  False
#    12A    25C     10.0   nan   nan   nan  False
#    12A    26A    -20.0   nan   nan   nan  False
#    12A    26B    -10.0   nan   nan   nan  False
#    12A    26C    -30.0   nan   nan   nan  False
#    12A    27A    -30.0   nan   nan   nan  False
#    12A    27B    -20.0   nan   nan   nan  False
#    12A    27C    -40.0   nan   nan   nan  False
#    12A    28A      0.0   nan   nan   nan  False
#    12A    28B     10.0   nan   nan   nan  False
#    12A    28C    -10.0   nan   nan   nan  False
#    12A    29A    -20.0   nan   nan   nan  False
#    12A    29B    -10.0   nan   nan   nan  False
#    12A    29C    -30.0   nan   nan   nan  False
#    12A     2A    -10.0   nan   nan   nan  False
#    12A     2B      0.0   nan   nan   nan  False
#    12A     2C    -20.0   nan   nan   nan  False
#    12A    30A    -10.0   nan   nan   nan  False
#    12A    30B      0.0   nan   nan   nan  False
#    12A    30C    -20.0   nan   nan   nan  False
#    12A     3A      0.0   nan   nan   nan  False
#    12A     3B     10.0   nan   nan   nan  False
#    12A     3C    -10.0   nan   nan   nan  False
#    12A     4A     10.0   nan   nan   nan  False
#    12A     4B     20.0   nan   nan   nan  False
#    12A     4C      0.0   nan   nan   nan  False
#    12A     5A     20.0   nan   nan   nan  False
#    12A     5B     30.0   nan   nan   nan  False
#    12A     5C     10.0   nan   nan   nan  False
#    12A     6A    -20.0   nan   nan   nan  False
#    12A     6B    -10.0   nan   nan   nan  False
#    12A     6C    -30.0   nan   nan   nan  False
#    12A     7A    -30.0   nan   nan   nan  False
#    12A     7B    -20.0   nan   nan   nan  False
#    12A     7C    -40.0   nan   nan   nan  False
#    12A     8A      0.0   nan   nan   nan  False
#    12A     8B     10.0   nan   nan   nan  False
#    12A     8C    -10.0   nan   nan   nan  False
#    12A     9A    -20.0   nan   nan   nan  False
#    12A     9B    -10.0   nan   nan   nan  False
#    12A     9C    -30.0   nan   nan   nan  False
#    12B    12C    -20.0   nan   nan   nan  False
#    12B    13A    -20.0   nan   nan   nan  False
#    12B    13B    -10.0   nan   nan   nan  False
#    12B    13C    -30.0   nan   nan   nan  False
#    12B    14A    -30.0   nan   nan   nan  False
#    12B    14B    -20.0   nan   nan   nan  False
#    12B    14C    -40.0   nan   nan   nan  False
#    12B    15A      0.0   nan   nan   nan  False
#    12B    15B     10.0   nan   nan   nan  False
#    12B    15C    -10.0   nan   nan   nan  False
#    12B    16A    -20.0   nan   nan   nan  False
#    12B    16B    -10.0   nan   nan   nan  False
#    12B    16C    -30.0   nan   nan   nan  False
#    12B    17A    -10.0   nan   nan   nan  False
#    12B    17B      0.0   nan   nan   nan  False
#    12B    17C    -20.0   nan   nan   nan  False
#    12B    18A      0.0   nan   nan   nan  False
#    12B    18B     10.0   nan   nan   nan  False
#    12B    18C    -10.0   nan   nan   nan  False
#    12B    19A     10.0   nan   nan   nan  False
#    12B    19B     20.0   nan   nan   nan  False
#    12B    19C      0.0   nan   nan   nan  False
#    12B     1A    -40.0   nan   nan   nan  False
#    12B     1B    -30.0   nan   nan   nan  False
#    12B     1C    -50.0   nan   nan   nan  False
#    12B    20A    -30.0   nan   nan   nan  False
#    12B    20B    -20.0   nan   nan   nan  False
#    12B    20C    -40.0   nan   nan   nan  False
#    12B    21A    -40.0   nan   nan   nan  False
#    12B    21B    -30.0   nan   nan   nan  False
#    12B    21C    -50.0   nan   nan   nan  False
#    12B    22A    -20.0   nan   nan   nan  False
#    12B    22B    -10.0   nan   nan   nan  False
#    12B    22C    -30.0   nan   nan   nan  False
#    12B    23A    -10.0   nan   nan   nan  False
#    12B    23B      0.0   nan   nan   nan  False
#    12B    23C    -20.0   nan   nan   nan  False
#    12B    24A      0.0   nan   nan   nan  False
#    12B    24B     10.0   nan   nan   nan  False
#    12B    24C    -10.0   nan   nan   nan  False
#    12B    25A     10.0   nan   nan   nan  False
#    12B    25B     20.0   nan   nan   nan  False
#    12B    25C      0.0   nan   nan   nan  False
#    12B    26A    -30.0   nan   nan   nan  False
#    12B    26B    -20.0   nan   nan   nan  False
#    12B    26C    -40.0   nan   nan   nan  False
#    12B    27A    -40.0   nan   nan   nan  False
#    12B    27B    -30.0   nan   nan   nan  False
#    12B    27C    -50.0   nan   nan   nan  False
#    12B    28A    -10.0   nan   nan   nan  False
#    12B    28B      0.0   nan   nan   nan  False
#    12B    28C    -20.0   nan   nan   nan  False
#    12B    29A    -30.0   nan   nan   nan  False
#    12B    29B    -20.0   nan   nan   nan  False
#    12B    29C    -40.0   nan   nan   nan  False
#    12B     2A    -20.0   nan   nan   nan  False
#    12B     2B    -10.0   nan   nan   nan  False
#    12B     2C    -30.0   nan   nan   nan  False
#    12B    30A    -20.0   nan   nan   nan  False
#    12B    30B    -10.0   nan   nan   nan  False
#    12B    30C    -30.0   nan   nan   nan  False
#    12B     3A    -10.0   nan   nan   nan  False
#    12B     3B      0.0   nan   nan   nan  False
#    12B     3C    -20.0   nan   nan   nan  False
#    12B     4A      0.0   nan   nan   nan  False
#    12B     4B     10.0   nan   nan   nan  False
#    12B     4C    -10.0   nan   nan   nan  False
#    12B     5A     10.0   nan   nan   nan  False
#    12B     5B     20.0   nan   nan   nan  False
#    12B     5C      0.0   nan   nan   nan  False
#    12B     6A    -30.0   nan   nan   nan  False
#    12B     6B    -20.0   nan   nan   nan  False
#    12B     6C    -40.0   nan   nan   nan  False
#    12B     7A    -40.0   nan   nan   nan  False
#    12B     7B    -30.0   nan   nan   nan  False
#    12B     7C    -50.0   nan   nan   nan  False
#    12B     8A    -10.0   nan   nan   nan  False
#    12B     8B      0.0   nan   nan   nan  False
#    12B     8C    -20.0   nan   nan   nan  False
#    12B     9A    -30.0   nan   nan   nan  False
#    12B     9B    -20.0   nan   nan   nan  False
#    12B     9C    -40.0   nan   nan   nan  False
#    12C    13A      0.0   nan   nan   nan  False
#    12C    13B     10.0   nan   nan   nan  False
#    12C    13C    -10.0   nan   nan   nan  False
#    12C    14A    -10.0   nan   nan   nan  False
#    12C    14B      0.0   nan   nan   nan  False
#    12C    14C    -20.0   nan   nan   nan  False
#    12C    15A     20.0   nan   nan   nan  False
#    12C    15B     30.0   nan   nan   nan  False
#    12C    15C     10.0   nan   nan   nan  False
#    12C    16A      0.0   nan   nan   nan  False
#    12C    16B     10.0   nan   nan   nan  False
#    12C    16C    -10.0   nan   nan   nan  False
#    12C    17A     10.0   nan   nan   nan  False
#    12C    17B     20.0   nan   nan   nan  False
#    12C    17C      0.0   nan   nan   nan  False
#    12C    18A     20.0   nan   nan   nan  False
#    12C    18B     30.0   nan   nan   nan  False
#    12C    18C     10.0   nan   nan   nan  False
#    12C    19A     30.0   nan   nan   nan  False
#    12C    19B     40.0   nan   nan   nan  False
#    12C    19C     20.0   nan   nan   nan  False
#    12C     1A    -20.0   nan   nan   nan  False
#    12C     1B    -10.0   nan   nan   nan  False
#    12C     1C    -30.0   nan   nan   nan  False
#    12C    20A    -10.0   nan   nan   nan  False
#    12C    20B      0.0   nan   nan   nan  False
#    12C    20C    -20.0   nan   nan   nan  False
#    12C    21A    -20.0   nan   nan   nan  False
#    12C    21B    -10.0   nan   nan   nan  False
#    12C    21C    -30.0   nan   nan   nan  False
#    12C    22A      0.0   nan   nan   nan  False
#    12C    22B     10.0   nan   nan   nan  False
#    12C    22C    -10.0   nan   nan   nan  False
#    12C    23A     10.0   nan   nan   nan  False
#    12C    23B     20.0   nan   nan   nan  False
#    12C    23C      0.0   nan   nan   nan  False
#    12C    24A     20.0   nan   nan   nan  False
#    12C    24B     30.0   nan   nan   nan  False
#    12C    24C     10.0   nan   nan   nan  False
#    12C    25A     30.0   nan   nan   nan  False
#    12C    25B     40.0   nan   nan   nan  False
#    12C    25C     20.0   nan   nan   nan  False
#    12C    26A    -10.0   nan   nan   nan  False
#    12C    26B      0.0   nan   nan   nan  False
#    12C    26C    -20.0   nan   nan   nan  False
#    12C    27A    -20.0   nan   nan   nan  False
#    12C    27B    -10.0   nan   nan   nan  False
#    12C    27C    -30.0   nan   nan   nan  False
#    12C    28A     10.0   nan   nan   nan  False
#    12C    28B     20.0   nan   nan   nan  False
#    12C    28C      0.0   nan   nan   nan  False
#    12C    29A    -10.0   nan   nan   nan  False
#    12C    29B      0.0   nan   nan   nan  False
#    12C    29C    -20.0   nan   nan   nan  False
#    12C     2A      0.0   nan   nan   nan  False
#    12C     2B     10.0   nan   nan   nan  False
#    12C     2C    -10.0   nan   nan   nan  False
#    12C    30A      0.0   nan   nan   nan  False
#    12C    30B     10.0   nan   nan   nan  False
#    12C    30C    -10.0   nan   nan   nan  False
#    12C     3A     10.0   nan   nan   nan  False
#    12C     3B     20.0   nan   nan   nan  False
#    12C     3C      0.0   nan   nan   nan  False
#    12C     4A     20.0   nan   nan   nan  False
#    12C     4B     30.0   nan   nan   nan  False
#    12C     4C     10.0   nan   nan   nan  False
#    12C     5A     30.0   nan   nan   nan  False
#    12C     5B     40.0   nan   nan   nan  False
#    12C     5C     20.0   nan   nan   nan  False
#    12C     6A    -10.0   nan   nan   nan  False
#    12C     6B      0.0   nan   nan   nan  False
#    12C     6C    -20.0   nan   nan   nan  False
#    12C     7A    -20.0   nan   nan   nan  False
#    12C     7B    -10.0   nan   nan   nan  False
#    12C     7C    -30.0   nan   nan   nan  False
#    12C     8A     10.0   nan   nan   nan  False
#    12C     8B     20.0   nan   nan   nan  False
#    12C     8C      0.0   nan   nan   nan  False
#    12C     9A    -10.0   nan   nan   nan  False
#    12C     9B      0.0   nan   nan   nan  False
#    12C     9C    -20.0   nan   nan   nan  False
#    13A    13B     10.0   nan   nan   nan  False
#    13A    13C    -10.0   nan   nan   nan  False
#    13A    14A    -10.0   nan   nan   nan  False
#    13A    14B      0.0   nan   nan   nan  False
#    13A    14C    -20.0   nan   nan   nan  False
#    13A    15A     20.0   nan   nan   nan  False
#    13A    15B     30.0   nan   nan   nan  False
#    13A    15C     10.0   nan   nan   nan  False
#    13A    16A      0.0   nan   nan   nan  False
#    13A    16B     10.0   nan   nan   nan  False
#    13A    16C    -10.0   nan   nan   nan  False
#    13A    17A     10.0   nan   nan   nan  False
#    13A    17B     20.0   nan   nan   nan  False
#    13A    17C      0.0   nan   nan   nan  False
#    13A    18A     20.0   nan   nan   nan  False
#    13A    18B     30.0   nan   nan   nan  False
#    13A    18C     10.0   nan   nan   nan  False
#    13A    19A     30.0   nan   nan   nan  False
#    13A    19B     40.0   nan   nan   nan  False
#    13A    19C     20.0   nan   nan   nan  False
#    13A     1A    -20.0   nan   nan   nan  False
#    13A     1B    -10.0   nan   nan   nan  False
#    13A     1C    -30.0   nan   nan   nan  False
#    13A    20A    -10.0   nan   nan   nan  False
#    13A    20B      0.0   nan   nan   nan  False
#    13A    20C    -20.0   nan   nan   nan  False
#    13A    21A    -20.0   nan   nan   nan  False
#    13A    21B    -10.0   nan   nan   nan  False
#    13A    21C    -30.0   nan   nan   nan  False
#    13A    22A      0.0   nan   nan   nan  False
#    13A    22B     10.0   nan   nan   nan  False
#    13A    22C    -10.0   nan   nan   nan  False
#    13A    23A     10.0   nan   nan   nan  False
#    13A    23B     20.0   nan   nan   nan  False
#    13A    23C      0.0   nan   nan   nan  False
#    13A    24A     20.0   nan   nan   nan  False
#    13A    24B     30.0   nan   nan   nan  False
#    13A    24C     10.0   nan   nan   nan  False
#    13A    25A     30.0   nan   nan   nan  False
#    13A    25B     40.0   nan   nan   nan  False
#    13A    25C     20.0   nan   nan   nan  False
#    13A    26A    -10.0   nan   nan   nan  False
#    13A    26B      0.0   nan   nan   nan  False
#    13A    26C    -20.0   nan   nan   nan  False
#    13A    27A    -20.0   nan   nan   nan  False
#    13A    27B    -10.0   nan   nan   nan  False
#    13A    27C    -30.0   nan   nan   nan  False
#    13A    28A     10.0   nan   nan   nan  False
#    13A    28B     20.0   nan   nan   nan  False
#    13A    28C      0.0   nan   nan   nan  False
#    13A    29A    -10.0   nan   nan   nan  False
#    13A    29B      0.0   nan   nan   nan  False
#    13A    29C    -20.0   nan   nan   nan  False
#    13A     2A      0.0   nan   nan   nan  False
#    13A     2B     10.0   nan   nan   nan  False
#    13A     2C    -10.0   nan   nan   nan  False
#    13A    30A      0.0   nan   nan   nan  False
#    13A    30B     10.0   nan   nan   nan  False
#    13A    30C    -10.0   nan   nan   nan  False
#    13A     3A     10.0   nan   nan   nan  False
#    13A     3B     20.0   nan   nan   nan  False
#    13A     3C      0.0   nan   nan   nan  False
#    13A     4A     20.0   nan   nan   nan  False
#    13A     4B     30.0   nan   nan   nan  False
#    13A     4C     10.0   nan   nan   nan  False
#    13A     5A     30.0   nan   nan   nan  False
#    13A     5B     40.0   nan   nan   nan  False
#    13A     5C     20.0   nan   nan   nan  False
#    13A     6A    -10.0   nan   nan   nan  False
#    13A     6B      0.0   nan   nan   nan  False
#    13A     6C    -20.0   nan   nan   nan  False
#    13A     7A    -20.0   nan   nan   nan  False
#    13A     7B    -10.0   nan   nan   nan  False
#    13A     7C    -30.0   nan   nan   nan  False
#    13A     8A     10.0   nan   nan   nan  False
#    13A     8B     20.0   nan   nan   nan  False
#    13A     8C      0.0   nan   nan   nan  False
#    13A     9A    -10.0   nan   nan   nan  False
#    13A     9B      0.0   nan   nan   nan  False
#    13A     9C    -20.0   nan   nan   nan  False
#    13B    13C    -20.0   nan   nan   nan  False
#    13B    14A    -20.0   nan   nan   nan  False
#    13B    14B    -10.0   nan   nan   nan  False
#    13B    14C    -30.0   nan   nan   nan  False
#    13B    15A     10.0   nan   nan   nan  False
#    13B    15B     20.0   nan   nan   nan  False
#    13B    15C      0.0   nan   nan   nan  False
#    13B    16A    -10.0   nan   nan   nan  False
#    13B    16B      0.0   nan   nan   nan  False
#    13B    16C    -20.0   nan   nan   nan  False
#    13B    17A      0.0   nan   nan   nan  False
#    13B    17B     10.0   nan   nan   nan  False
#    13B    17C    -10.0   nan   nan   nan  False
#    13B    18A     10.0   nan   nan   nan  False
#    13B    18B     20.0   nan   nan   nan  False
#    13B    18C      0.0   nan   nan   nan  False
#    13B    19A     20.0   nan   nan   nan  False
#    13B    19B     30.0   nan   nan   nan  False
#    13B    19C     10.0   nan   nan   nan  False
#    13B     1A    -30.0   nan   nan   nan  False
#    13B     1B    -20.0   nan   nan   nan  False
#    13B     1C    -40.0   nan   nan   nan  False
#    13B    20A    -20.0   nan   nan   nan  False
#    13B    20B    -10.0   nan   nan   nan  False
#    13B    20C    -30.0   nan   nan   nan  False
#    13B    21A    -30.0   nan   nan   nan  False
#    13B    21B    -20.0   nan   nan   nan  False
#    13B    21C    -40.0   nan   nan   nan  False
#    13B    22A    -10.0   nan   nan   nan  False
#    13B    22B      0.0   nan   nan   nan  False
#    13B    22C    -20.0   nan   nan   nan  False
#    13B    23A      0.0   nan   nan   nan  False
#    13B    23B     10.0   nan   nan   nan  False
#    13B    23C    -10.0   nan   nan   nan  False
#    13B    24A     10.0   nan   nan   nan  False
#    13B    24B     20.0   nan   nan   nan  False
#    13B    24C      0.0   nan   nan   nan  False
#    13B    25A     20.0   nan   nan   nan  False
#    13B    25B     30.0   nan   nan   nan  False
#    13B    25C     10.0   nan   nan   nan  False
#    13B    26A    -20.0   nan   nan   nan  False
#    13B    26B    -10.0   nan   nan   nan  False
#    13B    26C    -30.0   nan   nan   nan  False
#    13B    27A    -30.0   nan   nan   nan  False
#    13B    27B    -20.0   nan   nan   nan  False
#    13B    27C    -40.0   nan   nan   nan  False
#    13B    28A      0.0   nan   nan   nan  False
#    13B    28B     10.0   nan   nan   nan  False
#    13B    28C    -10.0   nan   nan   nan  False
#    13B    29A    -20.0   nan   nan   nan  False
#    13B    29B    -10.0   nan   nan   nan  False
#    13B    29C    -30.0   nan   nan   nan  False
#    13B     2A    -10.0   nan   nan   nan  False
#    13B     2B      0.0   nan   nan   nan  False
#    13B     2C    -20.0   nan   nan   nan  False
#    13B    30A    -10.0   nan   nan   nan  False
#    13B    30B      0.0   nan   nan   nan  False
#    13B    30C    -20.0   nan   nan   nan  False
#    13B     3A      0.0   nan   nan   nan  False
#    13B     3B     10.0   nan   nan   nan  False
#    13B     3C    -10.0   nan   nan   nan  False
#    13B     4A     10.0   nan   nan   nan  False
#    13B     4B     20.0   nan   nan   nan  False
#    13B     4C      0.0   nan   nan   nan  False
#    13B     5A     20.0   nan   nan   nan  False
#    13B     5B     30.0   nan   nan   nan  False
#    13B     5C     10.0   nan   nan   nan  False
#    13B     6A    -20.0   nan   nan   nan  False
#    13B     6B    -10.0   nan   nan   nan  False
#    13B     6C    -30.0   nan   nan   nan  False
#    13B     7A    -30.0   nan   nan   nan  False
#    13B     7B    -20.0   nan   nan   nan  False
#    13B     7C    -40.0   nan   nan   nan  False
#    13B     8A      0.0   nan   nan   nan  False
#    13B     8B     10.0   nan   nan   nan  False
#    13B     8C    -10.0   nan   nan   nan  False
#    13B     9A    -20.0   nan   nan   nan  False
#    13B     9B    -10.0   nan   nan   nan  False
#    13B     9C    -30.0   nan   nan   nan  False
#    13C    14A      0.0   nan   nan   nan  False
#    13C    14B     10.0   nan   nan   nan  False
#    13C    14C    -10.0   nan   nan   nan  False
#    13C    15A     30.0   nan   nan   nan  False
#    13C    15B     40.0   nan   nan   nan  False
#    13C    15C     20.0   nan   nan   nan  False
#    13C    16A     10.0   nan   nan   nan  False
#    13C    16B     20.0   nan   nan   nan  False
#    13C    16C      0.0   nan   nan   nan  False
#    13C    17A     20.0   nan   nan   nan  False
#    13C    17B     30.0   nan   nan   nan  False
#    13C    17C     10.0   nan   nan   nan  False
#    13C    18A     30.0   nan   nan   nan  False
#    13C    18B     40.0   nan   nan   nan  False
#    13C    18C     20.0   nan   nan   nan  False
#    13C    19A     40.0   nan   nan   nan  False
#    13C    19B     50.0   nan   nan   nan  False
#    13C    19C     30.0   nan   nan   nan  False
#    13C     1A    -10.0   nan   nan   nan  False
#    13C     1B      0.0   nan   nan   nan  False
#    13C     1C    -20.0   nan   nan   nan  False
#    13C    20A      0.0   nan   nan   nan  False
#    13C    20B     10.0   nan   nan   nan  False
#    13C    20C    -10.0   nan   nan   nan  False
#    13C    21A    -10.0   nan   nan   nan  False
#    13C    21B      0.0   nan   nan   nan  False
#    13C    21C    -20.0   nan   nan   nan  False
#    13C    22A     10.0   nan   nan   nan  False
#    13C    22B     20.0   nan   nan   nan  False
#    13C    22C      0.0   nan   nan   nan  False
#    13C    23A     20.0   nan   nan   nan  False
#    13C    23B     30.0   nan   nan   nan  False
#    13C    23C     10.0   nan   nan   nan  False
#    13C    24A     30.0   nan   nan   nan  False
#    13C    24B     40.0   nan   nan   nan  False
#    13C    24C     20.0   nan   nan   nan  False
#    13C    25A     40.0   nan   nan   nan  False
#    13C    25B     50.0   nan   nan   nan  False
#    13C    25C     30.0   nan   nan   nan  False
#    13C    26A      0.0   nan   nan   nan  False
#    13C    26B     10.0   nan   nan   nan  False
#    13C    26C    -10.0   nan   nan   nan  False
#    13C    27A    -10.0   nan   nan   nan  False
#    13C    27B      0.0   nan   nan   nan  False
#    13C    27C    -20.0   nan   nan   nan  False
#    13C    28A     20.0   nan   nan   nan  False
#    13C    28B     30.0   nan   nan   nan  False
#    13C    28C     10.0   nan   nan   nan  False
#    13C    29A      0.0   nan   nan   nan  False
#    13C    29B     10.0   nan   nan   nan  False
#    13C    29C    -10.0   nan   nan   nan  False
#    13C     2A     10.0   nan   nan   nan  False
#    13C     2B     20.0   nan   nan   nan  False
#    13C     2C      0.0   nan   nan   nan  False
#    13C    30A     10.0   nan   nan   nan  False
# ...
#     2A     7C    -30.0   nan   nan   nan  False
#     2A     8A     10.0   nan   nan   nan  False
#     2A     8B     20.0   nan   nan   nan  False
#     2A     8C      0.0   nan   nan   nan  False
#     2A     9A    -10.0   nan   nan   nan  False
#     2A     9B      0.0   nan   nan   nan  False
#     2A     9C    -20.0   nan   nan   nan  False
#     2B     2C    -20.0   nan   nan   nan  False
#     2B    30A    -10.0   nan   nan   nan  False
#     2B    30B      0.0   nan   nan   nan  False
#     2B    30C    -20.0   nan   nan   nan  False
#     2B     3A      0.0   nan   nan   nan  False
#     2B     3B     10.0   nan   nan   nan  False
#     2B     3C    -10.0   nan   nan   nan  False
#     2B     4A     10.0   nan   nan   nan  False
#     2B     4B     20.0   nan   nan   nan  False
#     2B     4C      0.0   nan   nan   nan  False
#     2B     5A     20.0   nan   nan   nan  False
#     2B     5B     30.0   nan   nan   nan  False
#     2B     5C     10.0   nan   nan   nan  False
#     2B     6A    -20.0   nan   nan   nan  False
#     2B     6B    -10.0   nan   nan   nan  False
#     2B     6C    -30.0   nan   nan   nan  False
#     2B     7A    -30.0   nan   nan   nan  False
#     2B     7B    -20.0   nan   nan   nan  False
#     2B     7C    -40.0   nan   nan   nan  False
#     2B     8A      0.0   nan   nan   nan  False
#     2B     8B     10.0   nan   nan   nan  False
#     2B     8C    -10.0   nan   nan   nan  False
#     2B     9A    -20.0   nan   nan   nan  False
#     2B     9B    -10.0   nan   nan   nan  False
#     2B     9C    -30.0   nan   nan   nan  False
#     2C    30A     10.0   nan   nan   nan  False
#     2C    30B     20.0   nan   nan   nan  False
#     2C    30C      0.0   nan   nan   nan  False
#     2C     3A     20.0   nan   nan   nan  False
#     2C     3B     30.0   nan   nan   nan  False
#     2C     3C     10.0   nan   nan   nan  False
#     2C     4A     30.0   nan   nan   nan  False
#     2C     4B     40.0   nan   nan   nan  False
#     2C     4C     20.0   nan   nan   nan  False
#     2C     5A     40.0   nan   nan   nan  False
#     2C     5B     50.0   nan   nan   nan  False
#     2C     5C     30.0   nan   nan   nan  False
#     2C     6A      0.0   nan   nan   nan  False
#     2C     6B     10.0   nan   nan   nan  False
#     2C     6C    -10.0   nan   nan   nan  False
#     2C     7A    -10.0   nan   nan   nan  False
#     2C     7B      0.0   nan   nan   nan  False
#     2C     7C    -20.0   nan   nan   nan  False
#     2C     8A     20.0   nan   nan   nan  False
#     2C     8B     30.0   nan   nan   nan  False
#     2C     8C     10.0   nan   nan   nan  False
#     2C     9A      0.0   nan   nan   nan  False
#     2C     9B     10.0   nan   nan   nan  False
#     2C     9C    -10.0   nan   nan   nan  False
#    30A    30B     10.0   nan   nan   nan  False
#    30A    30C    -10.0   nan   nan   nan  False
#    30A     3A     10.0   nan   nan   nan  False
#    30A     3B     20.0   nan   nan   nan  False
#    30A     3C      0.0   nan   nan   nan  False
#    30A     4A     20.0   nan   nan   nan  False
#    30A     4B     30.0   nan   nan   nan  False
#    30A     4C     10.0   nan   nan   nan  False
#    30A     5A     30.0   nan   nan   nan  False
#    30A     5B     40.0   nan   nan   nan  False
#    30A     5C     20.0   nan   nan   nan  False
#    30A     6A    -10.0   nan   nan   nan  False
#    30A     6B      0.0   nan   nan   nan  False
#    30A     6C    -20.0   nan   nan   nan  False
#    30A     7A    -20.0   nan   nan   nan  False
#    30A     7B    -10.0   nan   nan   nan  False
#    30A     7C    -30.0   nan   nan   nan  False
#    30A     8A     10.0   nan   nan   nan  False
#    30A     8B     20.0   nan   nan   nan  False
#    30A     8C      0.0   nan   nan   nan  False
#    30A     9A    -10.0   nan   nan   nan  False
#    30A     9B      0.0   nan   nan   nan  False
#    30A     9C    -20.0   nan   nan   nan  False
#    30B    30C    -20.0   nan   nan   nan  False
#    30B     3A      0.0   nan   nan   nan  False
#    30B     3B     10.0   nan   nan   nan  False
#    30B     3C    -10.0   nan   nan   nan  False
#    30B     4A     10.0   nan   nan   nan  False
#    30B     4B     20.0   nan   nan   nan  False
#    30B     4C      0.0   nan   nan   nan  False
#    30B     5A     20.0   nan   nan   nan  False
#    30B     5B     30.0   nan   nan   nan  False
#    30B     5C     10.0   nan   nan   nan  False
#    30B     6A    -20.0   nan   nan   nan  False
#    30B     6B    -10.0   nan   nan   nan  False
#    30B     6C    -30.0   nan   nan   nan  False
#    30B     7A    -30.0   nan   nan   nan  False
#    30B     7B    -20.0   nan   nan   nan  False
#    30B     7C    -40.0   nan   nan   nan  False
#    30B     8A      0.0   nan   nan   nan  False
#    30B     8B     10.0   nan   nan   nan  False
#    30B     8C    -10.0   nan   nan   nan  False
#    30B     9A    -20.0   nan   nan   nan  False
#    30B     9B    -10.0   nan   nan   nan  False
#    30B     9C    -30.0   nan   nan   nan  False
#    30C     3A     20.0   nan   nan   nan  False
#    30C     3B     30.0   nan   nan   nan  False
#    30C     3C     10.0   nan   nan   nan  False
#    30C     4A     30.0   nan   nan   nan  False
#    30C     4B     40.0   nan   nan   nan  False
#    30C     4C     20.0   nan   nan   nan  False
#    30C     5A     40.0   nan   nan   nan  False
#    30C     5B     50.0   nan   nan   nan  False
#    30C     5C     30.0   nan   nan   nan  False
#    30C     6A      0.0   nan   nan   nan  False
#    30C     6B     10.0   nan   nan   nan  False
#    30C     6C    -10.0   nan   nan   nan  False
#    30C     7A    -10.0   nan   nan   nan  False
#    30C     7B      0.0   nan   nan   nan  False
#    30C     7C    -20.0   nan   nan   nan  False
#    30C     8A     20.0   nan   nan   nan  False
#    30C     8B     30.0   nan   nan   nan  False
#    30C     8C     10.0   nan   nan   nan  False
#    30C     9A      0.0   nan   nan   nan  False
#    30C     9B     10.0   nan   nan   nan  False
#    30C     9C    -10.0   nan   nan   nan  False
#     3A     3B     10.0   nan   nan   nan  False
#     3A     3C    -10.0   nan   nan   nan  False
#     3A     4A     10.0   nan   nan   nan  False
#     3A     4B     20.0   nan   nan   nan  False
#     3A     4C      0.0   nan   nan   nan  False
#     3A     5A     20.0   nan   nan   nan  False
#     3A     5B     30.0   nan   nan   nan  False
#     3A     5C     10.0   nan   nan   nan  False
#     3A     6A    -20.0   nan   nan   nan  False
#     3A     6B    -10.0   nan   nan   nan  False
#     3A     6C    -30.0   nan   nan   nan  False
#     3A     7A    -30.0   nan   nan   nan  False
#     3A     7B    -20.0   nan   nan   nan  False
#     3A     7C    -40.0   nan   nan   nan  False
#     3A     8A      0.0   nan   nan   nan  False
#     3A     8B     10.0   nan   nan   nan  False
#     3A     8C    -10.0   nan   nan   nan  False
#     3A     9A    -20.0   nan   nan   nan  False
#     3A     9B    -10.0   nan   nan   nan  False
#     3A     9C    -30.0   nan   nan   nan  False
#     3B     3C    -20.0   nan   nan   nan  False
#     3B     4A      0.0   nan   nan   nan  False
#     3B     4B     10.0   nan   nan   nan  False
#     3B     4C    -10.0   nan   nan   nan  False
#     3B     5A     10.0   nan   nan   nan  False
#     3B     5B     20.0   nan   nan   nan  False
#     3B     5C      0.0   nan   nan   nan  False
#     3B     6A    -30.0   nan   nan   nan  False
#     3B     6B    -20.0   nan   nan   nan  False
#     3B     6C    -40.0   nan   nan   nan  False
#     3B     7A    -40.0   nan   nan   nan  False
#     3B     7B    -30.0   nan   nan   nan  False
#     3B     7C    -50.0   nan   nan   nan  False
#     3B     8A    -10.0   nan   nan   nan  False
#     3B     8B      0.0   nan   nan   nan  False
#     3B     8C    -20.0   nan   nan   nan  False
#     3B     9A    -30.0   nan   nan   nan  False
#     3B     9B    -20.0   nan   nan   nan  False
#     3B     9C    -40.0   nan   nan   nan  False
#     3C     4A     20.0   nan   nan   nan  False
#     3C     4B     30.0   nan   nan   nan  False
#     3C     4C     10.0   nan   nan   nan  False
#     3C     5A     30.0   nan   nan   nan  False
#     3C     5B     40.0   nan   nan   nan  False
#     3C     5C     20.0   nan   nan   nan  False
#     3C     6A    -10.0   nan   nan   nan  False
#     3C     6B      0.0   nan   nan   nan  False
#     3C     6C    -20.0   nan   nan   nan  False
#     3C     7A    -20.0   nan   nan   nan  False
#     3C     7B    -10.0   nan   nan   nan  False
#     3C     7C    -30.0   nan   nan   nan  False
#     3C     8A     10.0   nan   nan   nan  False
#     3C     8B     20.0   nan   nan   nan  False
#     3C     8C      0.0   nan   nan   nan  False
#     3C     9A    -10.0   nan   nan   nan  False
#     3C     9B      0.0   nan   nan   nan  False
#     3C     9C    -20.0   nan   nan   nan  False
#     4A     4B     10.0   nan   nan   nan  False
#     4A     4C    -10.0   nan   nan   nan  False
#     4A     5A     10.0   nan   nan   nan  False
#     4A     5B     20.0   nan   nan   nan  False
#     4A     5C      0.0   nan   nan   nan  False
#     4A     6A    -30.0   nan   nan   nan  False
#     4A     6B    -20.0   nan   nan   nan  False
#     4A     6C    -40.0   nan   nan   nan  False
#     4A     7A    -40.0   nan   nan   nan  False
#     4A     7B    -30.0   nan   nan   nan  False
#     4A     7C    -50.0   nan   nan   nan  False
#     4A     8A    -10.0   nan   nan   nan  False
#     4A     8B      0.0   nan   nan   nan  False
#     4A     8C    -20.0   nan   nan   nan  False
#     4A     9A    -30.0   nan   nan   nan  False
#     4A     9B    -20.0   nan   nan   nan  False
#     4A     9C    -40.0   nan   nan   nan  False
#     4B     4C    -20.0   nan   nan   nan  False
#     4B     5A      0.0   nan   nan   nan  False
#     4B     5B     10.0   nan   nan   nan  False
#     4B     5C    -10.0   nan   nan   nan  False
#     4B     6A    -40.0   nan   nan   nan  False
#     4B     6B    -30.0   nan   nan   nan  False
#     4B     6C    -50.0   nan   nan   nan  False
#     4B     7A    -50.0   nan   nan   nan  False
#     4B     7B    -40.0   nan   nan   nan  False
#     4B     7C    -60.0   nan   nan   nan  False
#     4B     8A    -20.0   nan   nan   nan  False
#     4B     8B    -10.0   nan   nan   nan  False
#     4B     8C    -30.0   nan   nan   nan  False
#     4B     9A    -40.0   nan   nan   nan  False
#     4B     9B    -30.0   nan   nan   nan  False
#     4B     9C    -50.0   nan   nan   nan  False
#     4C     5A     20.0   nan   nan   nan  False
#     4C     5B     30.0   nan   nan   nan  False
#     4C     5C     10.0   nan   nan   nan  False
#     4C     6A    -20.0   nan   nan   nan  False
#     4C     6B    -10.0   nan   nan   nan  False
#     4C     6C    -30.0   nan   nan   nan  False
#     4C     7A    -30.0   nan   nan   nan  False
#     4C     7B    -20.0   nan   nan   nan  False
#     4C     7C    -40.0   nan   nan   nan  False
#     4C     8A      0.0   nan   nan   nan  False
#     4C     8B     10.0   nan   nan   nan  False
#     4C     8C    -10.0   nan   nan   nan  False
#     4C     9A    -20.0   nan   nan   nan  False
#     4C     9B    -10.0   nan   nan   nan  False
#     4C     9C    -30.0   nan   nan   nan  False
#     5A     5B     10.0   nan   nan   nan  False
#     5A     5C    -10.0   nan   nan   nan  False
#     5A     6A    -40.0   nan   nan   nan  False
#     5A     6B    -30.0   nan   nan   nan  False
#     5A     6C    -50.0   nan   nan   nan  False
#     5A     7A    -50.0   nan   nan   nan  False
#     5A     7B    -40.0   nan   nan   nan  False
#     5A     7C    -60.0   nan   nan   nan  False
#     5A     8A    -20.0   nan   nan   nan  False
#     5A     8B    -10.0   nan   nan   nan  False
#     5A     8C    -30.0   nan   nan   nan  False
#     5A     9A    -40.0   nan   nan   nan  False
#     5A     9B    -30.0   nan   nan   nan  False
#     5A     9C    -50.0   nan   nan   nan  False
#     5B     5C    -20.0   nan   nan   nan  False
#     5B     6A    -50.0   nan   nan   nan  False
#     5B     6B    -40.0   nan   nan   nan  False
#     5B     6C    -60.0   nan   nan   nan  False
#     5B     7A    -60.0   nan   nan   nan  False
#     5B     7B    -50.0   nan   nan   nan  False
#     5B     7C    -70.0   nan   nan   nan  False
#     5B     8A    -30.0   nan   nan   nan  False
#     5B     8B    -20.0   nan   nan   nan  False
#     5B     8C    -40.0   nan   nan   nan  False
#     5B     9A    -50.0   nan   nan   nan  False
#     5B     9B    -40.0   nan   nan   nan  False
#     5B     9C    -60.0   nan   nan   nan  False
#     5C     6A    -30.0   nan   nan   nan  False
#     5C     6B    -20.0   nan   nan   nan  False
#     5C     6C    -40.0   nan   nan   nan  False
#     5C     7A    -40.0   nan   nan   nan  False
#     5C     7B    -30.0   nan   nan   nan  False
#     5C     7C    -50.0   nan   nan   nan  False
#     5C     8A    -10.0   nan   nan   nan  False
#     5C     8B      0.0   nan   nan   nan  False
#     5C     8C    -20.0   nan   nan   nan  False
#     5C     9A    -30.0   nan   nan   nan  False
#     5C     9B    -20.0   nan   nan   nan  False
#     5C     9C    -40.0   nan   nan   nan  False
#     6A     6B     10.0   nan   nan   nan  False
#     6A     6C    -10.0   nan   nan   nan  False
#     6A     7A    -10.0   nan   nan   nan  False
#     6A     7B      0.0   nan   nan   nan  False
#     6A     7C    -20.0   nan   nan   nan  False
#     6A     8A     20.0   nan   nan   nan  False
#     6A     8B     30.0   nan   nan   nan  False
#     6A     8C     10.0   nan   nan   nan  False
#     6A     9A      0.0   nan   nan   nan  False
#     6A     9B     10.0   nan   nan   nan  False
#     6A     9C    -10.0   nan   nan   nan  False
#     6B     6C    -20.0   nan   nan   nan  False
#     6B     7A    -20.0   nan   nan   nan  False
#     6B     7B    -10.0   nan   nan   nan  False
#     6B     7C    -30.0   nan   nan   nan  False
#     6B     8A     10.0   nan   nan   nan  False
#     6B     8B     20.0   nan   nan   nan  False
#     6B     8C      0.0   nan   nan   nan  False
#     6B     9A    -10.0   nan   nan   nan  False
#     6B     9B      0.0   nan   nan   nan  False
#     6B     9C    -20.0   nan   nan   nan  False
#     6C     7A      0.0   nan   nan   nan  False
#     6C     7B     10.0   nan   nan   nan  False
#     6C     7C    -10.0   nan   nan   nan  False
#     6C     8A     30.0   nan   nan   nan  False
#     6C     8B     40.0   nan   nan   nan  False
#     6C     8C     20.0   nan   nan   nan  False
#     6C     9A     10.0   nan   nan   nan  False
#     6C     9B     20.0   nan   nan   nan  False
#     6C     9C      0.0   nan   nan   nan  False
#     7A     7B     10.0   nan   nan   nan  False
#     7A     7C    -10.0   nan   nan   nan  False
#     7A     8A     30.0   nan   nan   nan  False
#     7A     8B     40.0   nan   nan   nan  False
#     7A     8C     20.0   nan   nan   nan  False
#     7A     9A     10.0   nan   nan   nan  False
#     7A     9B     20.0   nan   nan   nan  False
#     7A     9C      0.0   nan   nan   nan  False
#     7B     7C    -20.0   nan   nan   nan  False
#     7B     8A     20.0   nan   nan   nan  False
#     7B     8B     30.0   nan   nan   nan  False
#     7B     8C     10.0   nan   nan   nan  False
#     7B     9A      0.0   nan   nan   nan  False
#     7B     9B     10.0   nan   nan   nan  False
#     7B     9C    -10.0   nan   nan   nan  False
#     7C     8A     40.0   nan   nan   nan  False
#     7C     8B     50.0   nan   nan   nan  False
#     7C     8C     30.0   nan   nan   nan  False
#     7C     9A     20.0   nan   nan   nan  False
#     7C     9B     30.0   nan   nan   nan  False
#     7C     9C     10.0   nan   nan   nan  False
#     8A     8B     10.0   nan   nan   nan  False
#     8A     8C    -10.0   nan   nan   nan  False
#     8A     9A    -20.0   nan   nan   nan  False
#     8A     9B    -10.0   nan   nan   nan  False
#     8A     9C    -30.0   nan   nan   nan  False
#     8B     8C    -20.0   nan   nan   nan  False
#     8B     9A    -30.0   nan   nan   nan  False
#     8B     9B    -20.0   nan   nan   nan  False
#     8B     9C    -40.0   nan   nan   nan  False
#     8C     9A    -10.0   nan   nan   nan  False
#     8C     9B      0.0   nan   nan   nan  False
#     8C     9C    -20.0   nan   nan   nan  False
#     9A     9B     10.0   nan   nan   nan  False
#     9A     9C    -10.0   nan   nan   nan  False
#     9B     9C    -20.0   nan   nan   nan  False
# -----------------------------------------------
